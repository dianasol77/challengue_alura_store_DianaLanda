# %% [markdown]
# <a href="https://colab.research.google.com/github/dianasol77/challengue_alura_store_DianaLanda/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
suma_total_precio1 = tienda["Precio"].sum()
suma_total_precio2 = tienda2["Precio"].sum()
suma_total_precio3 = tienda3["Precio"].sum()
suma_total_precio4 = tienda4["Precio"].sum()

# %%
suma_total_precio1 = tienda["Precio"].sum()
suma_total_precio2 = tienda2["Precio"].sum()
suma_total_precio3 = tienda3["Precio"].sum()
suma_total_precio4 = tienda4["Precio"].sum()

print(f" el valor total de la tienda es {suma_total_precio1}")
print(f" el valor total de la tienda2 es {suma_total_precio2}")
print(f" el valor total de la tienda3 es {suma_total_precio3}")
print(f" el valor total de la tienda4 es {suma_total_precio4}")
# Out:
#  el valor total de la tienda es 1150880400.0
#  el valor total de la tienda2 es 1116343500.0
#  el valor total de la tienda3 es 1098019600.0
#  el valor total de la tienda4 es 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
vpc_tienda = tienda["Categoría del Producto"].value_counts()
vpc_tienda2 = tienda2["Categoría del Producto"].value_counts()
vpc_tienda3 = tienda3["Categoría del Producto"].value_counts()
vpc_tienda4 = tienda4["Categoría del Producto"].value_counts()

print(f"  Tienda 1 es {vpc_tienda}")
print(f"  Tienda 2 es {vpc_tienda2}")
print(f"  Tienda 3 es {vpc_tienda3}")
print(f"  Tienda 4 es {vpc_tienda4}")
# Out:
#   Tienda 1 es Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#   Tienda 2 es Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#   Tienda 3 es Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64
# ...

# %%
ventas_por_categoria = tienda.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria2 = tienda2.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria3 = tienda3.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria4 = tienda4.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)

print(f" Tienda 1 es {ventas_por_categoria}")
print(f" Tienda 2 es {ventas_por_categoria2}")
print(f" Tienda 3 es {ventas_por_categoria3}")
print(f" Tienda 4 es {ventas_por_categoria4}")
# Out:
#  Tienda 1 es                               Precio
# Categoría del Producto
# Electrónicos             429493500.0
# Electrodomésticos        363685200.0
# Muebles                  187633700.0
# Instrumentos musicales    91299000.0
# Deportes y diversión      39290000.0
# Juguetes                  17995700.0
# Artículos para el hogar   12698400.0
# Libros                     8784900.0
#  Tienda 2 es                               Precio
# Categoría del Producto
# Electrónicos             410831100.0
# Electrodomésticos        348567800.0
# Muebles                  176426300.0
# Instrumentos musicales   104990300.0
# Deportes y diversión      34744500.0
# Juguetes                  15945400.0
# Artículos para el hogar   14746900.0
# Libros                    10091200.0
#  Tienda 3 es                               Precio
# Categoría del Producto
# Electrónicos             410775800.0
# Electrodomésticos        329237900.0
# Muebles                  201072100.0
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular la calificación promedio para cada tienda
calificacion_promedio_tienda = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

# Mostrar resultados
print(f"\nCalificación Promedio - Tienda : {calificacion_promedio_tienda:.2f}")
print(f"Calificación Promedio - Tienda 2: {calificacion_promedio_tienda2:.2f}")
print(f"Calificación Promedio - Tienda 3: {calificacion_promedio_tienda3:.2f}")
print(f"Calificación Promedio - Tienda 4: {calificacion_promedio_tienda4:.2f}")
# Out:
# Calificación Promedio - Tienda : 3.98
# Calificación Promedio - Tienda 2: 4.04
# Calificación Promedio - Tienda 3: 4.05
# Calificación Promedio - Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def Productos_mas_menos_vendidos(data):
    # Agrupar por producto y sumar las facturaciones
    ventas_por_producto = data.groupby('Producto')['Precio'].sum().sort_values(ascending=False)

    # Obtener el producto con mayor facturación
    producto_mas_vendido = ventas_por_producto.idxmax(), ventas_por_producto.max()

    # Obtener el producto con menor facturación
    producto_menos_vendido = ventas_por_producto.idxmin(), ventas_por_producto.min()

    return producto_mas_vendido, producto_menos_vendido

# %%
# Calcular productos más y menos vendidos para cada tienda
mas_menos_tienda = Productos_mas_menos_vendidos(tienda)
mas_menos_tienda2 = Productos_mas_menos_vendidos(tienda2)
mas_menos_tienda3 = Productos_mas_menos_vendidos(tienda3)
mas_menos_tienda4 = Productos_mas_menos_vendidos(tienda4)

# Mostrar resultados
print(f"\nTienda 1 - Producto Más Vendido: {mas_menos_tienda[0][0]} (Cantidad: {mas_menos_tienda[0][1]})")
print(f"Tienda 1 - Producto Menos Vendido: {mas_menos_tienda[1][0]} (Cantidad: {mas_menos_tienda[1][1]})")

print(f"\nTienda 2 - Producto Más Vendido: {mas_menos_tienda2[0][0]} (Cantidad: {mas_menos_tienda2[0][1]})")
print(f"Tienda 2 - Producto Menos Vendido: {mas_menos_tienda2[1][0]} (Cantidad: {mas_menos_tienda2[1][1]})")

print(f"\nTienda 3 - Producto Más Vendido: {mas_menos_tienda3[0][0]} (Cantidad: {mas_menos_tienda3[0][1]})")
print(f"Tienda 3 - Producto Menos Vendido: {mas_menos_tienda3[1][0]} (Cantidad: {mas_menos_tienda3[1][1]})")

print(f"\nTienda 4 - Producto Más Vendido: {mas_menos_tienda4[0][0]} (Cantidad: {mas_menos_tienda4[0][1]})")
print(f"Tienda 4 - Producto Menos Vendido: {mas_menos_tienda4[1][0]} (Cantidad: {mas_menos_tienda4[1][1]})")
# Out:
# Tienda 1 - Producto Más Vendido: TV LED UHD 4K (Cantidad: 142150200.0)
# Tienda 1 - Producto Menos Vendido: Cuerda para saltar (Cantidad: 652800.0)
#
# Tienda 2 - Producto Más Vendido: Iphone 15 (Cantidad: 113225800.0)
# Tienda 2 - Producto Menos Vendido: Cubo mágico 8x8 (Cantidad: 643600.0)
#
# Tienda 3 - Producto Más Vendido: Refrigerador (Cantidad: 99889700.0)
# Tienda 3 - Producto Menos Vendido: Cubo mágico 8x8 (Cantidad: 640400.0)
#
# Tienda 4 - Producto Más Vendido: Iphone 15 (Cantidad: 96697500.0)
# Tienda 4 - Producto Menos Vendido: Cuerda para saltar (Cantidad: 704800.0)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def envio_promedio(data):
    # Calcular el costo de envío promedio
    promedio_envio = data['Costo de envío'].mean()
    return promedio_envio

# %%
# Calcular el envío promedio para cada tienda
envio_promedio_tienda = envio_promedio(tienda)
envio_promedio_tienda2 = envio_promedio(tienda2)
envio_promedio_tienda3 = envio_promedio(tienda3)
envio_promedio_tienda4 = envio_promedio(tienda4)

# Mostrar resultados
print(f"\nEnvío Promedio - Tienda 1: {envio_promedio_tienda:.2f}")
print(f"Envío Promedio - Tienda 2: {envio_promedio_tienda2:.2f}")
print(f"Envío Promedio - Tienda 3: {envio_promedio_tienda3:.2f}")
print(f"Envío Promedio - Tienda 4: {envio_promedio_tienda4:.2f}")
# Out:
# Envío Promedio - Tienda 1: 26018.61
# Envío Promedio - Tienda 2: 25216.24
# Envío Promedio - Tienda 3: 24805.68
# Envío Promedio - Tienda 4: 23459.46

# %% [markdown]
# **GRAFICOS**

# %%
pip install matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Gráfico 1: Ingresos por tienda
tientas = ['Tienda ', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [tienda['Precio'].sum(), tienda2['Precio'].sum(), tienda3['Precio'].sum(), tienda4['Precio'].sum()]

# %%
plt.figure(figsize=(10, 6))
plt.bar(tiendas, ingresos, color='skyblue')
plt.title('Ingresos por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Agregar una columna para identificar la tienda
tienda['Tienda'] = 'Tienda'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

# Concatenar todos los DataFrames
datos_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# Gráfico 1: Ingresos Totales por Tienda
ingresos_totales = datos_tiendas.groupby('Tienda')['Precio'].sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=ingresos_totales, x='Tienda', y='Precio', palette='viridis')
plt.title('Ingresos Totales por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# /tmp/ipython-input-2716623184.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_totales, x='Tienda', y='Precio', palette='viridis')

# %%
# Guardar cada DataFrame como un archivo CSV
tienda.to_csv('tienda_1.csv', sep=';', index=False)
tienda2.to_csv('tienda_2.csv', sep=';', index=False)
tienda3.to_csv('tienda_3.csv', sep=';', index=False)
tienda4.to_csv('tienda_4.csv', sep=';', index=False)

# Guardar el DataFrame combinado (si lo creaste)
datos_tiendas.to_csv('todas_tiendas.csv', sep=';', index=False)
